# %%
import pandas as pd
import os
import numpy as np

# %% [markdown]
# #### Input Query File

# %%
df1 =pd.read_csv("/Users/padana/Downloads/Abdullah/query.txt", sep='\t')
df1 = df1['Gene ID']

# %% [markdown]
# #### Data Comparison File with Input Query file

# %%
df2 =pd.read_csv("/Users/padana/Downloads/Abdullah/SRR8984343_gene_abun.out", sep='\t')
df2 = df2[df2['Gene ID'].str[0:3] != 'MST']
##df2 = df2['Gene ID']
#df2.head(1000)

# %%
#df_row = pd.concat([df1, df2], ignore_index=True)

#frames = [df1,df2]
#df_keys = pd.concat(frames, keys=['x', 'y'])

# %%
#df_inner = pd.merge(df1, df2, on='Gene ID', how='inner')
#df_inner

result = pd.merge(df1, df2, how='left', on=['Gene ID', 'Gene ID'])
result
# Out:
#                         Gene ID Gene Name     Reference Strand       Start  \
# 0     Pav_co3994625.1_g010.1.mk         -  PAV_r1.0chr5      -   7795814.0
# 1     Pav_sc0000002.1_g050.1.br       NaN           NaN    NaN         NaN
# 2     Pav_sc0000002.1_g150.1.br         .  PAV_r1.0chr4      +  25395326.0
# 3     Pav_sc0000002.1_g290.1.mk       NaN           NaN    NaN         NaN
# 4     Pav_sc0000002.1_g300.1.br         .  PAV_r1.0chr4      -  25362471.0
# 5     Pav_sc0000002.1_g350.1.mk       NaN           NaN    NaN         NaN
# 6     Pav_sc0000004.1_g100.1.br         -  PAV_r1.0chr7      +   8224655.0
# 7     Pav_sc0000006.1_g140.1.mk       NaN           NaN    NaN         NaN
# 8     Pav_sc0000006.1_g160.1.br       NaN           NaN    NaN         NaN
# 9     Pav_sc0000009.1_g150.1.br         -  PAV_r1.0chr3      -  20551638.0
# 10    Pav_sc0000009.1_g550.1.br       NaN           NaN    NaN         NaN
# ...

# %%
#result.to_csv(r'./Abdullah/Output.txt', index = False,header=True)

writer = pd.ExcelWriter('./Abdullah/Output.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
result.to_excel(writer, sheet_name='Sheet1')

# Close the Pandas Excel writer and output the Excel file.
writer.save()
